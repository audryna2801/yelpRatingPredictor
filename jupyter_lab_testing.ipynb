# %%
# %load_ext autoreload
# %autoreload 2
import crawl_and_scrape

# %%
import urllib.parse
import requests
import os
import bs4
import urllib3
import certifi
import json
import csv
import re
import time
import random

# %%
crawl_and_scrape.crawl_and_scrape(counter=15, city_url="https://www.yelp.com/search?find_desc=&find_loc=Chicago%2C%20IL",
                     csv_repo="scraped_data_2/")
# Out:
# sucess at this restauranthttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=0
# failure at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=20
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=40
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=60
# failure at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=80
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=100
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=120
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=140
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=160
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=180
# success at pagehttps://www.yelp.com/biz/lou-malnatis-pizzeria-chicago?start=200
# ...
